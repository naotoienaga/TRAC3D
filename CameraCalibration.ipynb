# %% [markdown]
# # Step 0: User Configuration and Mounting Your Drive
# **When using this program, be sure to run all the cells in this step from top to bottom once**

# %%
# Import libraries
import cv2
import numpy as np
import IPython
import plotly.graph_objects as go
from PIL import Image
from tqdm.notebook import tqdm
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Replace the following with your path and your desired parameters**

# %%
# --- File paths ---
# Video paths for intrinsic/extrinsic calibration
cam1_in_video_path = '/content/drive/MyDrive/Gesture/TRAC3D/videos/cam1_in.MP4'
cam2_in_video_path = '/content/drive/MyDrive/Gesture/TRAC3D/videos/cam2_in.MP4'
cam1_ex_video_path = '/content/drive/MyDrive/Gesture/TRAC3D/videos/cam1_ex.mp4'
cam2_ex_video_path = '/content/drive/MyDrive/Gesture/TRAC3D/videos/cam2_ex.mp4'

# Path for saving and loading intrinsic/extrinsic parameter
# The .npz file format is a NumPy archive used to save multiple arrays into a single fil
# Please do not change the '.npz' extension, as the program relies on it
cam1_in_param_path = '/content/drive/MyDrive/Gesture/TRAC3D/cam1_in.npz'
cam2_in_param_path = '/content/drive/MyDrive/Gesture/TRAC3D/cam2_in.npz'
ex_param_path = '/content/drive/MyDrive/Gesture/TRAC3D/ex.npz'

# Path where generated ChArUco board image will be saved
charuco_image_path = '/content/drive/MyDrive/Gesture/TRAC3D/charuco_board.png'


# --- ChArUco board properties ---
# Even x odd or odd x even combinations are generally recommended
# Appropriate size depends on size of board being printed, view range of video camera, and distance between camera and board
num_squares_x = 8  # Number of squares along the X axis (columns)
num_squares_y = 5  # Number of squares along the Y axis (rows)
# Physical dimensions of squares and markers (e.g., in meters)
square_length = 0.03  # Side length of each square
marker_length = square_length / 2  # Side length of each marker (must be < square_length)

# Select the type of ArUco dictionary (defines marker appearance and total unique markers), such as DICT_4X4_50 or DICT_7X7_1000
aruco_dictionary_id = cv2.aruco.DICT_6X6_250

# Image dimensions
image_width = 3840  # Width of output image in pixels
image_margin = image_width // 32  # Margin around the board in pixels


# --- Calibration hyperparameters ---
# Limits the number of valid frames to avoid excessive computation
# A smaller, high-quality set is usually sufficient for accurate calibration
# You might have to adjust these parameters again before calculating the external parameters
frame_sampling_interval = 20  # Process every N-th frame to reduce computation
max_valid_frame_pairs = 50    # Max number of valid frame pairs to collect
min_detected_corners = 20     # Min ChArUco corners for a valid detection. Must be less than or equal to (num_squares_x - 1) * (num_squares_y - 1)

# %%
# Load the predefined ArUco dictionary
aruco_dictionary = cv2.aruco.getPredefinedDictionary(aruco_dictionary_id)

# Create a ChArUco board with the given configuration
charuco_board = cv2.aruco.CharucoBoard(
    size=(num_squares_x, num_squares_y),
    squareLength=square_length,
    markerLength=marker_length,
    dictionary=aruco_dictionary
)

# %%
# Mount Google Drive to access your files in your Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Step 1: Generate and Save ChArUco Board Image
# **Download and print the saved board image, then use it to capture the calibration video**

# %%
# Calculate image height to preserve aspect ratio
charuco_img_height = int(image_width * num_squares_y / num_squares_x)

# Generate the ChArUco board image with given size and margin
charuco_image = cv2.aruco.CharucoBoard.generateImage(charuco_board,
    outSize=(image_width, charuco_img_height), marginSize=image_margin)

# Save the generated board image to the specified path
cv2.imwrite(charuco_image_path, charuco_image)

# Display preview for verification
cv2_imshow(cv2.resize(charuco_image, None, fx=0.25, fy=0.25))
# Out:
# <PIL.Image.Image image mode=L size=960x600>

# %% [markdown]
# # Step 2. Camera Calibration
#
# This script uses a ChArUco board and a video sequence of the board to perform camera calibration. It:
# 1. Loads a video file from two cameras.
# 2. Detects ChArUco patterns every N frames.
# 3. Extracts image and object points from valid frames.
# 4. Calculates the intrinsic parameters (camera matrix and distortion coefficients) for each camera individually
# 5. Saves the resulting camera parameters to a .npz file.
# 6. Calculates the extrinsic parameters (the rotation and translation that define the spatial relationship between the two cameras), following a similar procedure
#
#
# 'rmse' is the root mean square (RMS) reprojection error. It measures how well the estimated camera parameters match the observed image points. A smaller value indicates more accurate calibration.
# * rmse < 0.5: Very good calibration.
# * rmse ≈ 0.5 ~ 1.0: Sufficient for practical use.
# * rmse > 1.0: May indicate noise; consider improving image quality or board detection.
#
# `*` The above is only a guideline. RMS reprojection error is measured in pixels and can be affected by the size of the ChArUco board in the image. For example, if the board occupies most of the frame, even small detection errors can result in greater pixel deviation.

# %% [markdown]
# ## Helper Functions for Visualizing results for Debugging

# %%
# Just run

# Function to display detection result as gif
def display_gif(frames):
    gif_path = 'tmp.gif'
    frames[0].save(gif_path, save_all=True, append_images=frames[1:],
        loop=0, duration=500  # milliseconds per frame
    )
    return IPython.display.Image(gif_path, format='png')


# Create Plotly 3D lines for a camera frustum
def draw_camera_frustum(position, rotation_matrix, show_legend=True):
    width = 0.2
    height = 0.6 * width
    depth = 0.8 * width

    # Four corners on the plane in camera coords
    cam_corners = [
        np.array([+width / 2, -height / 2, depth]),
        np.array([-width / 2, -height / 2, depth]),
        np.array([-width / 2, +height / 2, depth]),
        np.array([+width / 2, +height / 2, depth])
    ]
    cam_center = position.flatten()

    # Transform corners to world frame
    world_corners = [cam_center + rotation_matrix @ c for c in cam_corners]

    # Lines from center to each corner
    lines = []
    for i, corner in enumerate(world_corners):
        lines.append(go.Scatter3d(
            x=[cam_center[0], corner[0]],
            y=[cam_center[1], corner[1]],
            z=[cam_center[2], corner[2]],
            mode='lines',
            line=dict(width=3, color='blue'),
            name='Camera',
            showlegend=True if (i == 0 and show_legend) else False,
            opacity=0.2
        ))

    # Edges of the plane
    for i in range(4):
        start = world_corners[i]
        end = world_corners[(i + 1) % 4]
        lines.append(go.Scatter3d(
            x=[start[0], end[0]],
            y=[start[1], end[1]],
            z=[start[2], end[2]],
            mode='lines',
            line=dict(width=3, color='blue'),
            showlegend=False,
            opacity=0.2
        ))

    return lines

# %% [markdown]
# ## Intrinsic Calibration

# %%
# Lists for visualizing results for debugging
visualizations1, visualizations2 = [[], None, None], [[], None, None]

for in_video_path, in_param_path, visualizations in zip(
        [cam1_in_video_path, cam2_in_video_path],
        [cam1_in_param_path, cam2_in_param_path],
        [visualizations1, visualizations2]
    ):

    # Open your videos
    cap = cv2.VideoCapture(in_video_path)

    # Get image dimensions from the first frame
    ret, frame = cap.read()
    if not ret:
        raise RuntimeError(f'Cannot read from {in_video_path}')

    frame_height, frame_width = frame.shape[:2]
    frame_size = (frame_width, frame_height)
    print(f'Frame size: {frame_size}')

    # For the progress bar if they're not matched
    num_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Setup ChArUco detector with refinement enabled
    charuco_params = cv2.aruco.CharucoParameters()
    charuco_params.tryRefineMarkers = True
    charuco_detector = cv2.aruco.CharucoDetector(charuco_board, charuco_params)

    termination_criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

    # Lists to store points from all valid paired frames
    object_points_list = []  # 3D points in board space
    image_points_list = []   # 2D points in camera

    # Progress tracking
    processed_frames = 1
    pbar = tqdm(total=num_frames, desc='Processing frames')
    pbar.update(1)

    # Main loop: read frames and detect ChArUco corners
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print('Finished processing videos or encountered an error reading frames')
            break

        processed_frames += 1
        pbar.update(1)

        # Skip frames based on the sampling interval
        if processed_frames % frame_sampling_interval != 0:
            continue

        # Convert to grayscale for detection
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect ChArUco board in both frames
        # Returns: charuco_corners, charuco_ids, marker_corners, marker_ids
        corners, ids, _, _ = charuco_detector.detectBoard(gray)

        # Skip if detection failed in either frame
        if ids is None:
            continue

        # Skip this frame if the number of detected corners is below the required minimum
        if len(ids) < min_detected_corners:
            continue

        # Refine corner locations for subpixel accuracy
        corners_refined = cv2.cornerSubPix(gray, corners, winSize=(11, 11),
            zeroZone=(-1, -1), criteria=termination_criteria)

        # Retrieve object and image points for each camera
        obj_pts, _ = charuco_board.matchImagePoints(corners_refined, ids)

        # Append
        object_points_list.append(obj_pts)
        image_points_list.append(corners_refined)

        # Prepare a view for GIF visualization
        cv2.aruco.drawDetectedCornersCharuco(frame, corners_refined, ids)
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.resize(frame, None, fx=0.5, fy=0.5)
        visualizations[0].append(Image.fromarray(frame))

        # Stop early if we've gathered enough valid frame pairs
        if len(image_points_list) >= max_valid_frame_pairs:
            print(f'Reached maximum valid frames ({max_valid_frame_pairs}). Stopping.')
            break

    # Release video resources and close progress bar
    cap.release()
    pbar.close()

    print(f"Collected {len(object_points_list)} valid frames.")

    rmse, cam_matrix, dist_coeffs, rvecs, tvecs = cv2.calibrateCamera(
        object_points_list, image_points_list, frame_size, None, None
    )

    # Print calibration results
    print("Calibration RMS error:", rmse)

    # Save calibration results
    np.savez(in_param_path, cam_matrix=cam_matrix, dist_coeffs=dist_coeffs)
    visualizations[1] = rvecs
    visualizations[2] = tvecs
# Out:
# Frame size: (1280, 720)
# Processing frames:   0%|          | 0/1065 [00:00<?, ?it/s]
# Finished processing videos or encountered an error reading frames
# Collected 45 valid frames.
# Calibration RMS error: 0.2982652394182614
# Frame size: (1280, 720)
# Processing frames:   0%|          | 0/1035 [00:00<?, ?it/s]
# Finished processing videos or encountered an error reading frames
# Collected 43 valid frames.
# Calibration RMS error: 0.26686621640397434

# %% [markdown]
# ## Visualizing results for Debugging (Intrinsic)

# %%
# Just run

def visualize_cam_board(rvecs, tvecs):
    # Assemble figure
    fig_data = []

    # Draw the ChArUco board
    board_width = num_squares_x * square_length
    board_height = num_squares_y * square_length
    pts_x = np.array([0, board_width, board_width, 0])
    pts_y = np.array([0, 0, board_height, board_height])
    pts_z = np.array([0, 0, 0, 0])
    fig_data.append(go.Mesh3d(x=pts_x, y=pts_y, z=pts_z,
                            i=[0, 0], j=[1, 2], k=[2, 3],
                            color='gray', name='Board', showlegend=True))

    # Calculate and draw the pose of the camera for each valid frame
    for idx, (rvec, tvec) in enumerate(zip(rvecs, tvecs)):

        # Calculate the rotation matrix
        R_board_to_cam, _ = cv2.Rodrigues(rvec)
        R_cam_to_board = R_board_to_cam.T

        # Calculate the translation vector
        t_board_to_cam = tvec
        t_cam_to_board = -R_board_to_cam.T @ t_board_to_cam

        # Use the calculated camera position and orientation to draw the camera frustum
        fig_data += draw_camera_frustum(t_cam_to_board, R_cam_to_board, (idx == 0))

    # Plot figure
    fig = go.Figure(data=fig_data)
    fig.update_layout(
        scene=dict(xaxis_title='X', yaxis_title='Y', zaxis_title='Z', aspectmode='data'),
        title='Fixed board and moving camera', showlegend=True
    )
    fig.show()

# %%
# Display detection result as gif
display(display_gif(visualizations1[0]))
display(display_gif(visualizations2[0]))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Visualize the spatial relationship between calibration board and camera
# Fixed ChArUco board's pose (XY plane)
# Moving camera's poses (positions and orientations) as 3D frustums (pyramids)
# Interactive 3D visualization allows you to move the viewing angle
visualize_cam_board(visualizations1[1], visualizations1[2])
visualize_cam_board(visualizations2[1], visualizations2[2])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bfa10bf8-362f-4a92-ba0f-94efc3b711fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfa10bf8-362f-4a92-ba0f-94efc3b711fc")) {                    Plotly.newPlot(                        "bfa10bf8-362f-4a92-ba0f-94efc3b711fc",                        [{"color":"gray","i":[0,0],"j":[1,2],"k":[2,3],"name":"Board","showlegend":true,"x":[0.0,0.24,0.24,0.0],"y":[0.0,0.0,0.15,0.15],"z":[0,0,0,0],"type":"mesh3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":true,"x":[0.11117656278962908,0.21508504394592637],"y":[0.09808943739157217,0.02799175671591668],"z":[-0.35385993799572185,-0.20059760502481458],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.11117656278962908,0.015151947174023087],"y":[0.09808943739157217,0.028236392544492256],"z":[-0.35385993799572185,-0.19543069409969435],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.11117656278962908,0.015493986534511214],"y":[0.09808943739157217,0.1479972174966953],"z":[-0.35385993799572185,-0.18786578723684047],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.11117656278962908,0.21542708330641452],"y":[0.09808943739157217,0.14775258166811975],"z":[-0.35385993799572185,-0.1930326981619607],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.21508504394592637,0.015151947174023087],"y":[0.02799175671591668,0.028236392544492256],"z":[-0.20059760502481458,-0.19543069409969435],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.015151947174023087,0.015493986534511214],"y":[0.028236392544492256,0.1479972174966953],"z":[-0.19543069409969435,-0.18786578723684047],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.015493986534511214,0.21542708330641452],"y":[0.1479972174966953,0.14775258166811975],"z":[-0.18786578723684047,-0.1930326981619607],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.21542708330641452,0.21508504394592637],"y":[0.14775258166811975,0.02799175671591668],"z":[-0.1930326981619607,-0.20059760502481458],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.12248407891905821,0.22420662483257842],"y":[0.09476880857629225,0.02535534793142341],"z":[-0.367388239603958,-0.2123582581997953],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.12248407891905821,0.024239727612448775],"y":[0.09476880857629225,0.027303931415103427],"z":[-0.367388239603958,-0.20928530545670943],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.12248407891905821,0.025505352317465618],"y":[0.09476880857629225,0.14712768133853552],"z":[-0.367388239603958,-0.20290822552990467],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.12248407891905821,0.22547224953759526],"y":[0.09476880857629225,0.1451790978548555],"z":[-0.367388239603958,-0.20598117827299056],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.22420662483257842,0.024239727612448775],"y":[0.02535534793142341,0.027303931415103427],"z":[-0.2123582581997953,-0.20928530545670943],"type":"scatter ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="db41626f-eb04-4e43-8317-be0814eeb9e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db41626f-eb04-4e43-8317-be0814eeb9e4")) {                    Plotly.newPlot(                        "db41626f-eb04-4e43-8317-be0814eeb9e4",                        [{"color":"gray","i":[0,0],"j":[1,2],"k":[2,3],"name":"Board","showlegend":true,"x":[0.0,0.24,0.24,0.0],"y":[0.0,0.0,0.15,0.15],"z":[0,0,0,0],"type":"mesh3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":true,"x":[0.11844061453946254,0.21917572059048318],"y":[0.10217704748178288,0.032838457127928655],"z":[-0.39701749794952423,-0.24131072771576068],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.11844061453946254,0.019178295729064362],"y":[0.10217704748178288,0.031997375828639985],"z":[-0.39701749794952423,-0.2407427215105866],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.11844061453946254,0.018695643155166544],"y":[0.10217704748178288,0.15176758756832076],"z":[-0.39701749794952423,-0.23333573654199458],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.11844061453946254,0.2186930680165854],"y":[0.10217704748178288,0.15260866886760943],"z":[-0.39701749794952423,-0.23390374274716866],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.21917572059048318,0.019178295729064362],"y":[0.032838457127928655,0.031997375828639985],"z":[-0.24131072771576068,-0.2407427215105866],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.019178295729064362,0.018695643155166544],"y":[0.031997375828639985,0.15176758756832076],"z":[-0.2407427215105866,-0.23333573654199458],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.018695643155166544,0.2186930680165854],"y":[0.15176758756832076,0.15260866886760943],"z":[-0.23333573654199458,-0.23390374274716866],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.2186930680165854,0.21917572059048318],"y":[0.15260866886760943,0.032838457127928655],"z":[-0.23390374274716866,-0.24131072771576068],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.12043328297286442,0.21990053283417882],"y":[0.10507713106514802,0.03630460218028969],"z":[-0.3916672022708796,-0.23489792761602832],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.12043328297286442,0.01990151813506308],"y":[0.10507713106514802,0.03648383081879063],"z":[-0.3916672022708796,-0.23549958904742635],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.12043328297286442,0.019989098662527294],"y":[0.10507713106514802,0.15630325038226606],"z":[-0.3916672022708796,-0.22891938957301436],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.12043328297286442,0.21998811336164303],"y":[0.10507713106514802,0.1561240217437651],"z":[-0.3916672022708796,-0.22831772814161633],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.21990053283417882,0.01990151813506308],"y":[0.03630460218028969,0.03648383081879063],"z":[-0.23489792761602832,-0.23549958904742635],"type":"sc ...

# %% [markdown]
# ## Extrinsic Calibration

# %%
# Open your videos
cap1 = cv2.VideoCapture(cam1_ex_video_path)
cap2 = cv2.VideoCapture(cam2_ex_video_path)

# Get image dimensions from the first frame of camera 1 (assuming both cameras have same resolution)
ret1, frame1 = cap1.read()
if not ret1:
    raise RuntimeError(f'Cannot read from {cam1_ex_video_path}')

frame_height, frame_width = frame1.shape[:2]
frame_size = (frame_width, frame_height)
print(f'Frame size: {frame_size}')

# Discard the first frame of camera 2 to sync videos
cap2.read()

# Use the shorter video length for the progress bar if they're not matched
total_frames1 = int(cap1.get(cv2.CAP_PROP_FRAME_COUNT))
total_frames2 = int(cap2.get(cv2.CAP_PROP_FRAME_COUNT))
if total_frames1 != total_frames2:
    print('WARNING: The number of frames in the two videos does not match. They are supposed to be synchronized.')
num_frames = min(total_frames1, total_frames2)

# Setup ChArUco detector with refinement enabled
charuco_params = cv2.aruco.CharucoParameters()
charuco_params.tryRefineMarkers = True
charuco_detector = cv2.aruco.CharucoDetector(charuco_board, charuco_params)

# Termination criteria for corner subpixel refinement
termination_criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# Lists to store points from all valid paired frames
object_points_list = []    # 3D points in board space
image_points_list1 = []    # 2D points in camera 1
image_points_list2 = []    # 2D points in camera 2
visualization_frames = []  # Frames for optional GIF creation

# Progress tracking
processed_frames = 1
pbar = tqdm(total=num_frames, desc='Processing frames')
pbar.update(1)

# Main loop: read frames and detect ChArUco corners
while cap1.isOpened() and cap2.isOpened():

    ret1, frame1 = cap1.read()
    ret2, frame2 = cap2.read()
    if not ret1 or not ret2:
        print('Finished processing videos or encountered an error reading frames')
        break

    processed_frames += 1
    pbar.update(1)

    # Skip frames based on the sampling interval
    if processed_frames % frame_sampling_interval != 0:
        continue

    # Convert to grayscale for detection
    gray1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)

    # Detect ChArUco board in both frames
    # Returns: charuco_corners, charuco_ids, marker_corners, marker_ids
    corners1, ids1, _, _ = charuco_detector.detectBoard(gray1)
    corners2, ids2, _, _ = charuco_detector.detectBoard(gray2)

    # Skip if detection failed in either frame
    if ids1 is None or ids2 is None:
        continue

    # Find common marker IDs in both views
    common_ids = np.intersect1d(ids1.flatten(), ids2.flatten())
    if len(common_ids) < min_detected_corners:
        continue

    # Refine corner locations for subpixel accuracy
    corners1_refined = cv2.cornerSubPix(gray1, corners1, winSize=(11, 11),
        zeroZone=(-1, -1), criteria=termination_criteria)
    corners2_refined = cv2.cornerSubPix(gray2, corners2, winSize=(11, 11),
        zeroZone=(-1, -1), criteria=termination_criteria)

    # Retrieve object and image points for each camera
    obj_pts1, img_pts1 = charuco_board.matchImagePoints(corners1_refined, ids1)
    _, img_pts2 = charuco_board.matchImagePoints(corners2_refined, ids2)

    # Collect matching points across both cameras
    pts3d, pts2d_cam1, pts2d_cam2 = [], [], []
    for cid in common_ids:
        idx1 = np.where(ids1 == cid)[0][0]
        idx2 = np.where(ids2 == cid)[0][0]

        # Append the corresponding 3D object point from the board
        pts3d.append(obj_pts1[idx1])  # Use obj_points from cam1 (or cam2, as they are equal)

        # Append the detected 2D image points from both cameras
        pts2d_cam1.append(img_pts1[idx1])
        pts2d_cam2.append(img_pts2[idx2])

    object_points_list.append(np.array(pts3d, dtype=np.float32))
    image_points_list1.append(np.array(pts2d_cam1, dtype=np.float32))
    image_points_list2.append(np.array(pts2d_cam2, dtype=np.float32))

    # Prepare a combined view for GIF visualization
    cv2.aruco.drawDetectedCornersCharuco(frame1, corners1_refined, ids1)
    cv2.aruco.drawDetectedCornersCharuco(frame2, corners2_refined, ids2)
    combined = cv2.hconcat([frame1, frame2])
    combined = cv2.resize(combined, None, fx=0.5, fy=0.5)
    combined = cv2.cvtColor(combined, cv2.COLOR_BGR2RGB)
    visualization_frames.append(Image.fromarray(combined))

    # Stop early if we've gathered enough valid frame pairs
    if len(object_points_list) >= max_valid_frame_pairs:
        print(f'Reached maximum valid frames ({max_valid_frame_pairs}). Stopping.')
        break

# Release video resources and close progress bar
cap1.release()
cap2.release()
pbar.close()

print(f"Collected {len(object_points_list)} valid frame pairs.")

# Load intrinsic parameters
params = np.load(cam1_in_param_path)
cam_matrix1 = params['cam_matrix']
dist_coeffs1 = params['dist_coeffs']
params = np.load(cam1_in_param_path)
cam_matrix2 = params['cam_matrix']
dist_coeffs2 = params['dist_coeffs']

rmse, _, _, _, _, rotation, translation, _, _ = cv2.stereoCalibrate(
    object_points_list, image_points_list1, image_points_list2,
    cam_matrix1, dist_coeffs1, cam_matrix2, dist_coeffs2,
    frame_size, flags=cv2.CALIB_FIX_INTRINSIC
)

# Print calibration results
print("Calibration RMS error:", rmse)

# Save calibration results
np.savez(ex_param_path, rotation=rotation, translation=translation)
# Out:
# Frame size: (1280, 720)
# Processing frames:   0%|          | 0/1889 [00:00<?, ?it/s]
# Finished processing videos or encountered an error reading frames
# Collected 49 valid frame pairs.
# Calibration RMS error: 0.6100177974144071

# %% [markdown]
# ## Visualizing results for Debugging (Extrinsic)

# %%
# Display detection result as gif
display(display_gif(visualization_frames))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Visualize the spatial relationship between calibration board and cameras
# Moving ChArUco board's poses (XY plane)
# Fixed cameras' poses (positions and orientations) as 3D frustums (pyramids)
# Interactive 3D visualization allows you to move the viewing angle

# Assemble figure
fig_data = []

# Camera 1 at origin
fig_data += draw_camera_frustum(
    position=np.zeros((3, 1)),
    rotation_matrix=np.eye(3)
)

# Camera 2 pose from calibration
fig_data += draw_camera_frustum(
    position=-rotation.T @ translation.reshape(3, 1),
    rotation_matrix=rotation.T
)

# Define board corners
board_width = num_squares_x * square_length
board_height = num_squares_y * square_length
board_corners = np.array([
    [0, 0, 0],
    [board_width, 0, 0],
    [board_width, board_height, 0],
    [0, board_height, 0]
])

# Calculate rotation and translation of boards
_, _, _, board_rvecs_cam1, board_tvecs_cam1 = cv2.calibrateCamera(
    objectPoints=object_points_list,
    imagePoints=image_points_list1,
    imageSize=frame_size,
    cameraMatrix=cam_matrix1,
    distCoeffs=dist_coeffs1
)

# Add each board pose as a semi-transparent Mesh3d
for idx, (rvec, tvec) in enumerate(zip(board_rvecs_cam1, board_tvecs_cam1)):
    rot_board, _ = cv2.Rodrigues(rvec)
    trans_board = tvec.reshape(3, 1)
    world_pts = [(rot_board @ corner.reshape(3, 1) + trans_board).flatten()
                 for corner in board_corners]
    pts_x = [p[0] for p in world_pts]
    pts_y = [p[1] for p in world_pts]
    pts_z = [p[2] for p in world_pts]
    fig_data.append(go.Mesh3d(x=pts_x, y=pts_y, z=pts_z,
        i=[0, 0], j=[1, 2], k=[2, 3],
        opacity=0.2, name='Board', showlegend=(idx == 0)))

# Plot figure
fig = go.Figure(data=fig_data)
fig.update_layout(
    scene=dict(xaxis_title='X', yaxis_title='Y', zaxis_title='Z', aspectmode='data'),
    title='Two cameras and moving board', showlegend=True
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6da865a3-9910-4399-a76e-4dcd526b66af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6da865a3-9910-4399-a76e-4dcd526b66af")) {                    Plotly.newPlot(                        "6da865a3-9910-4399-a76e-4dcd526b66af",                        [{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":true,"x":[0.0,0.1],"y":[0.0,-0.06],"z":[0.0,0.16000000000000003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.0,-0.1],"y":[0.0,-0.06],"z":[0.0,0.16000000000000003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.0,-0.1],"y":[0.0,0.06],"z":[0.0,0.16000000000000003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.0,0.1],"y":[0.0,0.06],"z":[0.0,0.16000000000000003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.1,-0.1],"y":[-0.06,-0.06],"z":[0.16000000000000003,0.16000000000000003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[-0.1,-0.1],"y":[-0.06,0.06],"z":[0.16000000000000003,0.16000000000000003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[-0.1,0.1],"y":[0.06,0.06],"z":[0.16000000000000003,0.16000000000000003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.1,0.1],"y":[0.06,-0.06],"z":[0.16000000000000003,0.16000000000000003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":true,"x":[0.636235164728797,0.6806052710554845],"y":[0.0007338447656397728,-0.06332716501004453],"z":[0.142720078381182,0.3247296404681178],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.636235164728797,0.4903598861346691],"y":[0.0007338447656397728,-0.0573713630407237],"z":[0.142720078381182,0.2633193649498218],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.636235164728797,0.4935043878597209],"y":[0.0007338447656397728,0.06257252266950193],"z":[0.142720078381182,0.265210499433003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","name":"Camera","opacity":0.2,"showlegend":false,"x":[0.636235164728797,0.6837497727805363],"y":[0.0007338447656397728,0.05661672070018109],"z":[0.142720078381182,0.32662077495129904],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.6806052710554845,0.4903598861346691],"y":[-0.06332716501004453,-0.0573713630407237],"z":[0.3247296404681178,0.2633193649498218],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.4903598861346691,0.4935043878597209],"y":[-0.0573713630407237,0.06257252266950193],"z":[0.2633193649498218,0.265210499433003],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.4935043878597209,0.6837497727805363],"y":[0.06257252266950193,0.05661672070018109],"z":[0.265210499433003,0.32662077495129904],"type":"scatter3d"},{"line":{"color":"blue","width":3},"mode":"lines","opacity":0.2,"showlegend":false,"x":[0.6837497727805363,0.6806052710554845],"y":[0.05661672070018109,-0.06332716501004453],"z":[0.32662077495129904,0.3247296404681178],"type":"scatter3d"},{"i":[0,0],"j":[1,2],"k":[2,3],"nam ...
